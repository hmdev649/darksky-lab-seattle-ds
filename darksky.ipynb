# %% [markdown]
# Create a function which will take the Season as an argument and execute the following:

# %%
import sqlite3
import pymongo
import pandas as pd
# import dnspython
import json
import requests
from collections import Counter

# %%
# initialize sql cursor
conn = sqlite3.connect('database.sqlite')
cur = conn.cursor()

# %%
#do the join for 
# cur.execute("""
#             select * from Unique_Teams UT 
#             join Teams_in_Matches TM on UT.Unique_Team_ID = TM.Unique_Team_Id
#             join Matches on TM.Match_ID = Matches.Match_ID
#             join Teams on UT.TeamName = Teams.TeamName
#             where Date between '2011-08-01' and '2013-05-31'
#             order by TM.Match_ID asc
# """).fetchmany(3)


cur.execute("""
            select * from Matches as M
            join Teams_in_Matches as TM on M.Match_ID = TM.Match_ID
            join Unique_Teams as UT on TM.Unique_Team_ID = UT.Unique_Team_ID
            where Date between '2011-08-01' and '2013-05-31'
            order by M.Match_ID asc
""").fetchmany(10)



# Match ID, Div, Season, Match Date, Home Team Name, Away Team Name, Home Score, Away Score, Winning Team Status, Match ID, Team ID, Team Name, Team ID
# Out:
# [(1092,
#   'D1',
#   2011,
#   '2012-03-31',
#   'Nurnberg',
#   'Bayern Munich',
#   0,
#   1,
#   'A',
#   1092,
#   1,
#   'Bayern Munich',
#   1),
#  (1092,
#   'D1',
#   2011,
#   '2012-03-31',
#   'Nurnberg',
#   'Bayern Munich',
#   0,
#   1,
#   'A',
#   1092,
#   22,
#   'Nurnberg',
#   22),
#  (1093,
#   'D1',
#   2011,
#   '2011-12-11',
#   'Stuttgart',
#   'Bayern Munich',
#   1,
#   2,
#   'A',
#   1093,
#   1,
#   'Bayern Munich',
#   1),
#  (1093,
#   'D1',
#   2011,
#   '2011-12-11',
#   'Stuttgart',
#   'Bayern Munich',
#   1,
#   2,
#   'A',
#   1093,
#   17,
#   'Stuttgart',
#   17),
#  (1094,
#   'D1',
#   2011,
#   '2011-08-13',
#   'Wolfsburg',
#   'Bayern Munich',
#   0,
#   1,
#   'A',
#   1094,
#   1,
#   'Bayern Munich',
#   1),
#  (1094,
#   'D1',
#   2011,
#   '2011-08-13',
#   'Wolfsburg',
#   'Bayern Munich',
#   0,
#   1,
#   'A',
#   1094,
#   7,
#   'Wolfsburg',
#   7),
#  (1095,
#   'D1',
#   2011,
#   '2011-11-27',
#   'Mainz',
# ...

# %%
cur.execute("""
            select * from Matches as M
            join Unique_Teams as UT on UT.TeamName = M.HomeTeam
            where Date between '2011-08-01' and '2013-05-31'
            order by M.Match_ID asc
""").fetchmany(2)
# Out:
# [(1092,
#   'D1',
#   2011,
#   '2012-03-31',
#   'Nurnberg',
#   'Bayern Munich',
#   0,
#   1,
#   'A',
#   'Nurnberg',
#   22),
#  (1093,
#   'D1',
#   2011,
#   '2011-12-11',
#   'Stuttgart',
#   'Bayern Munich',
#   1,
#   2,
#   'A',
#   'Stuttgart',
#   17)]

# %%
# import all tables into dataframes
df_M = pd.DataFrame(cur.execute(""" select * from Matches where Date between '2011-08-01' and '2013-05-31' order by Date asc """).fetchall())
df_M.columns = ['Match_ID', 'Div', 'Season', 'Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR']

# df_Teams = pd.DataFrame(cur.execute(""" select * from Teams """).fetchall())
# df_Teams.columns = ['Season', 'TeamName', 'KaterHome', 'AvgAgeHome', 'ForeignPlayersHome', 'OverallMarketValueHome', 'AvgMarketValueHome', 'StadiumCapacity']
              
df_UT = pd.DataFrame(cur.execute(""" select * from Unique_Teams """).fetchall())
df_UT.columns = ['TeamName', 'Unique_Team_ID']

df_TM = pd.DataFrame(cur.execute(""" select * from Teams_in_Matches """).fetchall())
df_TM.columns = ['Match_ID', 'Unique_Team_ID']

# %%
# # count wins at home by team
# df_Home = df_M[df_M['FTR'] == 'H']
# cnt_home = Counter()
# for t in df_UT['TeamName']:
#     for i in df_Home['HomeTeam']:
#         if t == i:
#             cnt_home[t]+=1
# print(cnt_home)


# # count wins at away by team
# df_away = df_M[df_M['FTR'] == 'A']
# cnt_away = Counter()
# for t in df_UT['TeamName']:
#     for i in df_away['AwayTeam']:
#         if t == i:
#             cnt_away[t]+=1
# print(cnt_away)


# cnt_goals = Counter()
# for t in df_UT['TeamName']:
#     for i in df_M['HomeTeam']

# for i in cnt:
#     if 

# df_M[df_M['FTR'] == 'H'

    
# print(df_M.head())

# for i in df_M['Match_ID']:
#     if df_M['HomeTeam'][i] = df_TM['TM'][i]:
        
df_h = df_M.groupby(['HomeTeam', 'FTR']).agg({'FTR':'count', 'FTHG':'sum'})
# print(df_h.info())
df_a = df_M.groupby(['AwayTeam']).agg({'FTR':'count', 'FTAG':'sum'})
# df_a['HomeTeam'] = df_a['AwayTeam']
# print(df_a.info())
df_a
# df_a['AwayTeam', 'FTR']
# df.set_index('key').join(other.set_index('key'))

# df_h.set_index(['HomeTeam', 'FTR']).join(df_a.set_index(['HomeTeam', 'FTR']))
# df_h.head()
# print(df_h['FTHG'] + df_a['FTAG'])

# with pd.option_context('display.max_rows', 999):
#     print (df_h)
# Out:
#              FTR  FTAG
# AwayTeam
# Aachen        16    15
# Aalen         17    16
# Arsenal       38    60
# Aston Villa   38    41
# Augsburg      34    30
# ...          ...   ...
# West Brom     38    45
# West Ham      19    11
# Wigan         38    41
# Wolfsburg     34    44
# Wolves        19    21
#
# [62 rows x 2 columns]

# %%
df_a.reset_index()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-246-9769de8b5188> in <module>
# ----> 1 df_a.reset_index()
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    4692                 # to ndarray and maybe infer different dtype
#    4693                 level_values = _maybe_casted_values(lev, lab)
# -> 4694                 new_obj.insert(0, name, level_values)
#    4695
#    4696         new_obj.index = new_index
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    3574         self._ensure_valid_index(value)
#    3575         value = self._sanitize_column(column, value, broadcast=False)
# -> 3576         self._data.insert(loc, column, value, allow_duplicates=allow_duplicates)
# ...

# %%
df_Home = df_M.drop(['AwayTeam', 'FTAG'], axis=1)
print(df_Home.head())
df_Away = df_M.drop(['HomeTeam', 'FTHG'], axis=1)
print(df_Away.head())
# Out:
#    Match_ID Div  Season        Date            HomeTeam  FTHG FTR
# 0      1219  D1    2011  2011-08-05            Dortmund     3   H
# 1      1545  D2    2011  2011-08-05            St Pauli     3   H
# 2      1613  D2    2011  2011-08-05        Union Berlin     3   H
# 3      1684  D2    2011  2011-08-05  Fortuna Dusseldorf     4   H
# 4      1130  D2    2011  2011-08-06      Greuther Furth     1   H
#    Match_ID Div  Season        Date    AwayTeam  FTAG FTR
# 0      1219  D1    2011  2011-08-05     Hamburg     1   H
# 1      1545  D2    2011  2011-08-05      Aachen     1   H
# 2      1613  D2    2011  2011-08-05   Paderborn     0   H
# 3      1684  D2    2011  2011-08-05  Ingolstadt     1   H
# 4      1130  D2    2011  2011-08-06     Dresden     0   H

# %%
df_Away['HomeTeam'] = df_Away['AwayTeam']

# %%
df_Home.merge(df_Away, on='HomeTeam')
df_Home.head()
# Out:
#    Match_ID Div  Season        Date            HomeTeam  FTHG FTR
# 0      1219  D1    2011  2011-08-05            Dortmund     3   H
# 1      1545  D2    2011  2011-08-05            St Pauli     3   H
# 2      1613  D2    2011  2011-08-05        Union Berlin     3   H
# 3      1684  D2    2011  2011-08-05  Fortuna Dusseldorf     4   H
# 4      1130  D2    2011  2011-08-06      Greuther Furth     1   H

# %%
# def pipeline(season):
 
# Insert data into MongoDB Atlas where each record contains the following information:
    # Team Name (this is from the 'Teams' table)
    # League (either English Premier League (E0) or Bundesliga (D1)) (this is also from 'Matches' table)
    # Season ('Teams/Matches')
    # Total number of goals scored by the team during the season (this will come from 'Matches')
    # Total number of wins the team earned during the season (this will also come from 'Matches')
    
    # Team's win percentage on days where it was raining during games in the season
    # pull rain data from DarkSky API for Berlin specifically

final = pd.DataFrame(df_Teams['TeamName'])
final['Div'] = df_Matches['Div']
final['Season'] = df_Matches['Season']
final['FTHG'] = df_Matches['FTHG']
final
#     pass
# Out:
#           TeamName Div  Season  FTHG
# 0    Bayern Munich  D1    2011     3
# 1         Dortmund  D2    2011     3
# 2       Leverkusen  D2    2011     3
# 3       RB Leipzig  D2    2011     4
# 4       Schalke 04  D2    2011     1
# ..             ...  ..     ...   ...
# 463      Paderborn  E0    2011     1
# 464   Unterhaching  D2    2011     2
# 465      Offenbach  E0    2011     1
# 466         Siegen  E0    2011     2
# 467   Braunschweig  E0    2011     1
#
# [468 rows x 4 columns]

# %%
df_Matches.to_json('Matches.json')
df_Teams.to_json('Teams.json')
df_U_Teams.to_json('U_Teams.json')
df_T_in_M.to_json('T_in_M.json')

# %%
#write a query to pull all data where date is between aug 2011 and may 2013

df_matches.filter()

# %%
# initialize connection to MongoDBAtlas and insert json files
with open('.secrets_mongodb') as f:
    pw = f.read().strip()
client = pymongo.MongoClient(f"mongodb+srv://hmdev649:{pw}@flatiron-ds-szqfd.mongodb.net/test?retryWrites=true&w=majority")
db = client.FIFA

# %%
# insert JSON files to collections in MongoDB Atlas
collection_name = 'Matches'
db_M = db[collection_name]
with open(r'Matches.json', 'r') as data_file1:
    data_json1 = json.load(data_file1)
db_M.insert_one(data_json1)

# %%
collection_name = 'Teams'
db_T = db[collection_name]
with open(r'Teams.json', 'r') as data_file2:
    data_json2 = json.load(data_file2)  
db_T.insert_one(data_json2)

collection_name = 'Teams_in_Matches'
db_MT = db[collection_name]
with open(r'T_in_M.json', 'r') as data_file3:
    data_json3 = json.load(data_file3)
db_MT.insert_one(data_json3)

collection_name = 'Unique_Teams'
db_UT = db[collection_name]
with open(r'U_Teams.json', 'r') as data_file4:
    data_json4 = json.load(data_file4)  
db_UT.insert_one(data_json4)

# %%
# pull in Dark Sky data

with open('.secrets') as f:
    pw2 = f.read().strip()

response = requests.get(f'https://api.darksky.net/forecast/{pw2}/52.5200, 13.4050')
data = json.loads(response.text)
data
# Out:
# {'latitude': 52.52,
#  'longitude': 13.405,
#  'timezone': 'Europe/Berlin',
#  'currently': {'time': 1581105739,
#   'summary': 'Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 40.31,
#   'apparentTemperature': 37.42,
#   'dewPoint': 35.91,
#   'humidity': 0.84,
#   'pressure': 1028.6,
#   'windSpeed': 4.29,
#   'windGust': 7.72,
#   'windBearing': 142,
#   'cloudCover': 0.34,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 314.3},
#  'hourly': {'summary': 'Clear throughout the day.',
#   'icon': 'clear-day',
#   'data': [{'time': 1581105600,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 40.33,
#     'apparentTemperature': 37.47,
#     'dewPoint': 35.91,
#     'humidity': 0.84,
#     'pressure': 1028.6,
#     'windSpeed': 4.26,
#     'windGust': 7.65,
#     'windBearing': 142,
# ...
